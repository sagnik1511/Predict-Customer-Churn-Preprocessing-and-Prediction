# %% [markdown]
# # Customer Churn Prediction :
#
# In this project we'll see how to perform a data preprocessing and data prediction in intermediate level.
# So, in this dataset we have train on the dataset which has multiple numerical and categorical feaatures and predict over the data.
#
#
# ![](https://miro.medium.com/max/750/1*8_Md5Ns2OKeW9F8XRRCMKg.jpeg)
#
#
# ## UPVOTE if you like this notebook :)
# You can see my other works in [sagnik1511](https://kaggle.com/sagnik1511/notebooks) or in [github](github.com/sagnik1511)

# %% [markdown]
# ## Libraries :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Gathering & Primary Visualization:
#
# At first we have to read the data .
# Then we'll overview on the data and prepare a process how to edit the data.

# %%
train_df=pd.read_csv('../input/churn-risk-rate-hackerearth-ml/train.csv')
train_df.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_time_spent  \
# 0                      No    xxxxxxxx  ...         300.63
# 1                       ?    CID21329  ...         306.34
# 2                     Yes    CID12313  ...         516.16
# 3                     Yes     CID3793  ...          53.27
# 4                      No    xxxxxxxx  ...         113.13
#
#   avg_transaction_value avg_frequency_login_days points_in_wallet  \
# 0              53005.25                     17.0           781.75
# 1              12838.38                     10.0              NaN
# 2              21027.00                     22.0           500.69
# 3              25239.56                      6.0           567.66
# 4              24483.66                     16.0           663.06
#
#    used_special_discount  offer_application_preference  past_complaint  \
# 0                    Yes                           Yes              No
# 1                    Yes                            No             Yes
# 2                     No                           Yes             Yes
# 3                     No                           Yes             Yes
# 4                     No                           Yes             Yes
#
#       complaint_status                  feedback churn_risk_score
# 0       Not Applicable  Products always in Stock                2
# 1               Solved     Quality Customer Care                1
# 2  Solved in Follow-up              Poor Website                5
# 3             Unsolved              Poor Website                5
# 4               Solved              Poor Website                5
#
# [5 rows x 25 columns]

# %%
test_df=pd.read_csv('../input/churn-risk-rate-hackerearth-ml/test.csv')
test_df.head()
# Out:
#                             customer_id              Name  age gender  \
# 0  fffe43004900440031003700300030003400    Alethia Meints   50      F
# 1  fffe43004900440031003900370037003300        Ming Lopez   41      M
# 2  fffe43004900440034003800360037003000  Carina Flannigan   31      F
# 3  fffe43004900440036003200370033003400      Kyung Wanner   64      M
# 4  fffe43004900440035003000370031003900       Enola Gatto   16      F
#
#   security_no region_category membership_category joining_date  \
# 0     OQJ1XAY         Village  Premium Membership   2015-11-02
# 1     OUQRPKO         Village     Gold Membership   2016-03-01
# 2     02J2RE7            Town   Silver Membership   2017-03-03
# 3     5YEQIF1            Town   Silver Membership   2017-08-18
# 4     100RYB5            Town       No Membership   2015-05-05
#
#   joined_through_referral referral_id  ... days_since_last_login  \
# 0                      No    xxxxxxxx  ...                    12
# 1                      No    xxxxxxxx  ...                    11
# 2                      No    xxxxxxxx  ...                    18
# 3                     Yes     CID8941  ...                  -999
# 4                     Yes     CID5690  ...                     6
#
#   avg_time_spent avg_transaction_value avg_frequency_login_days  \
# 0         386.26              40721.44                      7.0
# 1          37.80               9644.40                      9.0
# 2         215.36               3693.25                     21.0
# 3          44.57              36809.56                     11.0
# 4         349.88              40675.86                      8.0
#
#    points_in_wallet  used_special_discount  offer_application_preference  \
# 0        733.830000                    Yes                            No
# 1        726.000000                    Yes                            No
# 2        713.780000                    Yes                            No
# 3        744.970000                    Yes                            No
# 4        299.048351                     No                           Yes
#
#   past_complaint          complaint_status              feedback
# 0             No            Not Applicable  Poor Product Quality
# 1             No            Not Applicable          Poor Website
# 2            Yes       Solved in Follow-up   No reason specified
# 3            Yes  No Information Available          Too many ads
# 4            Yes       Solved in Follow-up          Poor Website
#
# [5 rows x 24 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36992 entries, 0 to 36991
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   36992 non-null  object
#  1   Name                          36992 non-null  object
#  2   age                           36992 non-null  int64
#  3   gender                        36992 non-null  object
#  4   security_no                   36992 non-null  object
#  5   region_category               31564 non-null  object
#  6   membership_category           36992 non-null  object
#  7   joining_date                  36992 non-null  object
#  8   joined_through_referral       36992 non-null  object
#  9   referral_id                   36992 non-null  object
#  10  preferred_offer_types         36704 non-null  object
#  11  medium_of_operation           36992 non-null  object
#  12  internet_option               36992 non-null  object
#  13  last_visit_time               36992 non-null  object
#  14  days_since_last_login         36992 non-null  int64
#  15  avg_time_spent                36992 non-null  float64
#  16  avg_transaction_value         36992 non-null  float64
#  17  avg_frequency_login_days      36992 non-null  object
#  18  points_in_wallet              33549 non-null  float64
#  19  used_special_discount         36992 non-null  object
#  20  offer_application_preference  36992 non-null  object
#  21  past_complaint                36992 non-null  object
#  22  complaint_status              36992 non-null  object
#  23  feedback                      36992 non-null  object
#  24  churn_risk_score              36992 non-null  int64
# dtypes: float64(3), int64(3), object(19)
# memory usage: 7.1+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19919 entries, 0 to 19918
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   19919 non-null  object
#  1   Name                          19919 non-null  object
#  2   age                           19919 non-null  int64
#  3   gender                        19919 non-null  object
#  4   security_no                   19919 non-null  object
#  5   region_category               16971 non-null  object
#  6   membership_category           19919 non-null  object
#  7   joining_date                  19919 non-null  object
#  8   joined_through_referral       19919 non-null  object
#  9   referral_id                   19919 non-null  object
#  10  preferred_offer_types         19760 non-null  object
#  11  medium_of_operation           19919 non-null  object
#  12  internet_option               19919 non-null  object
#  13  last_visit_time               19919 non-null  object
#  14  days_since_last_login         19919 non-null  int64
#  15  avg_time_spent                19919 non-null  float64
#  16  avg_transaction_value         19919 non-null  float64
#  17  avg_frequency_login_days      19919 non-null  object
#  18  points_in_wallet              17956 non-null  float64
#  19  used_special_discount         19919 non-null  object
#  20  offer_application_preference  19919 non-null  object
#  21  past_complaint                19919 non-null  object
#  22  complaint_status              19919 non-null  object
#  23  feedback                      19919 non-null  object
# dtypes: float64(3), int64(2), object(19)
# memory usage: 3.6+ MB

# %% [markdown]
# Now we are going to check the number of output/target values has.

# %%
train_df['churn_risk_score'].unique()
# Out:
# array([ 2,  1,  5,  3,  4, -1])

# %% [markdown]
# It is visible that there are 6 target values and we have to classify them.
#
# It is the final **objective**.

# %% [markdown]
# # Data Preprocessing :
#
# After visualizing the data we have planned some moves to process the data.
#
# In this process we have seen that both the train and test data leakage.
#
# So , basically we are going to take the following moves to prepare trainable and predictable data.

# %% [markdown]
# #### Filling leakages :
#
# As the data have lekagaes we have to fill those.
# and in this process we have taken two techniques. --
#
# |Data Types|Will be filled with|
# |---|---|
# |Categorical data|a string named 'None'|
# |Numerical Data|Mean of the present values|

# %%
for col in test_df.columns:
    if train_df[col].isnull().sum()!=0 or test_df[col].isnull().sum()!=0:
        if train_df[col].dtype=='int64':
            value=int(np.mean(train_df[col]))
            train_df[col].fillna(value,inplace=True)
            test_df[col].fillna(value,inplace=True)
        elif train_df[col].dtype=='float64':
            value=np.mean(train_df[col])
            train_df[col].fillna(value,inplace=True)
            test_df[col].fillna(value,inplace=True)
        else:
            train_df[col].fillna('None',inplace=True)
            test_df[col].fillna('None',inplace=True)

# %%
train_df.isnull().sum()
# Out:
# customer_id                     0
# Name                            0
# age                             0
# gender                          0
# security_no                     0
# region_category                 0
# membership_category             0
# joining_date                    0
# joined_through_referral         0
# referral_id                     0
# preferred_offer_types           0
# medium_of_operation             0
# internet_option                 0
# last_visit_time                 0
# days_since_last_login           0
# avg_time_spent                  0
# avg_transaction_value           0
# avg_frequency_login_days        0
# points_in_wallet                0
# used_special_discount           0
# offer_application_preference    0
# past_complaint                  0
# complaint_status                0
# feedback                        0
# churn_risk_score                0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# customer_id                     0
# Name                            0
# age                             0
# gender                          0
# security_no                     0
# region_category                 0
# membership_category             0
# joining_date                    0
# joined_through_referral         0
# referral_id                     0
# preferred_offer_types           0
# medium_of_operation             0
# internet_option                 0
# last_visit_time                 0
# days_since_last_login           0
# avg_time_spent                  0
# avg_transaction_value           0
# avg_frequency_login_days        0
# points_in_wallet                0
# used_special_discount           0
# offer_application_preference    0
# past_complaint                  0
# complaint_status                0
# feedback                        0
# dtype: int64

# %% [markdown]
# #### Dropping Unnecessary Fearures:
#
# we have seen that there are some name and id features, when we are going to predict over the data , we can definitely tell these features only helps to label the dta , but it won't be helpful when it is time for prediction so we are going to drop those features.

# %%
train_df.shape
# Out:
# (36992, 25)

# %%
cl_train_df=train_df.drop(labels=['customer_id','Name','security_no','referral_id','feedback'],axis=1)
cl_test_df=test_df.drop(labels=['customer_id','Name','security_no','referral_id','feedback'],axis=1)

# %%
cl_train_df.shape
# Out:
# (36992, 20)

# %% [markdown]
# # Change the time series datas :
#
# In this part we are going to numerate and create seperate columns for each value.

# %%
type(cl_train_df['joining_date'][0])
# Out:
# str

# %% [markdown]
# As the type of the data isn't datettime series , we have to do it manually.

# %%
def add_dates(data):
    df=data
    day=[]
    month=[]
    year=[]
    for i in range(len(data)):
        year.append(int(data['joining_date'][i][:4]))
        month.append(int(data['joining_date'][i][5:7]))
        day.append(int(data['joining_date'][i][8:10]))
    df['day']=day
    df['month']=month
    df['year']=year
    return df

# %%
train_1=add_dates(cl_train_df)
test_1=add_dates(cl_test_df)

# %%
train_1.drop('joining_date',1,inplace=True)
test_1.drop('joining_date',1,inplace=True)

# %%
train_1.head()
# Out:
#    age gender region_category  membership_category joined_through_referral  \
# 0   18      F         Village  Platinum Membership                      No
# 1   32      F            City   Premium Membership                       ?
# 2   44      F            Town        No Membership                     Yes
# 3   37      M            City        No Membership                     Yes
# 4   31      F            City        No Membership                      No
#
#       preferred_offer_types medium_of_operation internet_option  \
# 0     Gift Vouchers/Coupons                   ?           Wi-Fi
# 1     Gift Vouchers/Coupons             Desktop     Mobile_Data
# 2     Gift Vouchers/Coupons             Desktop           Wi-Fi
# 3     Gift Vouchers/Coupons             Desktop     Mobile_Data
# 4  Credit/Debit Card Offers          Smartphone     Mobile_Data
#
#   last_visit_time  days_since_last_login  ...  avg_frequency_login_days  \
# 0        16:08:02                     17  ...                      17.0
# 1        12:38:13                     16  ...                      10.0
# 2        22:53:21                     14  ...                      22.0
# 3        15:57:50                     11  ...                       6.0
# 4        15:46:44                     20  ...                      16.0
#
#    points_in_wallet used_special_discount  offer_application_preference  \
# 0        781.750000                   Yes                           Yes
# 1        686.882199                   Yes                            No
# 2        500.690000                    No                           Yes
# 3        567.660000                    No                           Yes
# 4        663.060000                    No                           Yes
#
#   past_complaint     complaint_status churn_risk_score day  month  year
# 0             No       Not Applicable                2  17      8  2017
# 1            Yes               Solved                1  28      8  2017
# 2            Yes  Solved in Follow-up                5  11     11  2016
# 3            Yes             Unsolved                5  29     10  2016
# 4            Yes               Solved                5  12      9  2017
#
# [5 rows x 22 columns]

# %%
def add_time(data):
    df=data
    hour=[]
    mint=[]
    second=[]
    for i in range(len(data)):
        hour.append(int(data['last_visit_time'][i][:2]))
        mint.append(int(data['last_visit_time'][i][3:5]))
        second.append(int(data['last_visit_time'][i][6:8]))
        
    data['minute']=mint
    data['hour']=hour
    data['sec']=second
    data.drop('last_visit_time',1,inplace=True)
    return df

# %%
train=add_time(train_1)
test=add_time(test_1)

# %%
train.head()
# Out:
#    age gender region_category  membership_category joined_through_referral  \
# 0   18      F         Village  Platinum Membership                      No
# 1   32      F            City   Premium Membership                       ?
# 2   44      F            Town        No Membership                     Yes
# 3   37      M            City        No Membership                     Yes
# 4   31      F            City        No Membership                      No
#
#       preferred_offer_types medium_of_operation internet_option  \
# 0     Gift Vouchers/Coupons                   ?           Wi-Fi
# 1     Gift Vouchers/Coupons             Desktop     Mobile_Data
# 2     Gift Vouchers/Coupons             Desktop           Wi-Fi
# 3     Gift Vouchers/Coupons             Desktop     Mobile_Data
# 4  Credit/Debit Card Offers          Smartphone     Mobile_Data
#
#    days_since_last_login  avg_time_spent  ...  offer_application_preference  \
# 0                     17          300.63  ...                           Yes
# 1                     16          306.34  ...                            No
# 2                     14          516.16  ...                           Yes
# 3                     11           53.27  ...                           Yes
# 4                     20          113.13  ...                           Yes
#
#   past_complaint     complaint_status churn_risk_score day month  year  \
# 0             No       Not Applicable                2  17     8  2017
# 1            Yes               Solved                1  28     8  2017
# 2            Yes  Solved in Follow-up                5  11    11  2016
# 3            Yes             Unsolved                5  29    10  2016
# 4            Yes               Solved                5  12     9  2017
#
#    minute  hour  sec
# 0       8    16    2
# 1      38    12   13
# 2      53    22   21
# 3      57    15   50
# 4      46    15   44
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Feature Encoding :
#
# Now we have check if any categorical feature has more than 20 unique values , then we will omit that cause too much variety in dtaa will simply make the dataset more complex to predict correctly.

# %%
for col in test_1.columns:
    if train_1[col].dtype=='object':
        print(col)
# Out:
# gender
# region_category
# membership_category
# joined_through_referral
# preferred_offer_types
# medium_of_operation
# internet_option
# avg_frequency_login_days
# used_special_discount
# offer_application_preference
# past_complaint
# complaint_status

# %%
for col in test.columns:
    if train[col].dtype=='object':
        if train[col].nunique() >20:
            train.drop(col,1,inplace=True)
            test.drop(col,1,inplace=True)
        else:
            k=0
            for val in train[col].value_counts().index:
                train[col].replace(val,k,inplace=True)
                test[col].replace(val,k,inplace=True)
                k+=1

# %%
train.head()
# Out:
#    age  gender  region_category  membership_category  joined_through_referral  \
# 0   18       0                3                    5                        0
# 1   32       0                1                    4                        2
# 2   44       0                0                    1                        1
# 3   37       1                1                    1                        1
# 4   31       0                1                    1                        0
#
#    preferred_offer_types  medium_of_operation  internet_option  \
# 0                      0                    2                0
# 1                      0                    0                1
# 2                      0                    0                0
# 3                      0                    0                1
# 4                      1                    1                1
#
#    days_since_last_login  avg_time_spent  ...  offer_application_preference  \
# 0                     17          300.63  ...                             0
# 1                     16          306.34  ...                             1
# 2                     14          516.16  ...                             0
# 3                     11           53.27  ...                             0
# 4                     20          113.13  ...                             0
#
#    past_complaint  complaint_status  churn_risk_score  day  month  year  \
# 0               0                 0                 2   17      8  2017
# 1               1                 2                 1   28      8  2017
# 2               1                 3                 5   11     11  2016
# 3               1                 1                 5   29     10  2016
# 4               1                 2                 5   12      9  2017
#
#    minute  hour  sec
# 0       8    16    2
# 1      38    12   13
# 2      53    22   21
# 3      57    15   50
# 4      46    15   44
#
# [5 rows x 23 columns]

# %%
test.head()
# Out:
#    age  gender  region_category  membership_category  joined_through_referral  \
# 0   50       0                3                    4                        0
# 1   41       1                3                    2                        0
# 2   31       0                0                    3                        0
# 3   64       1                0                    3                        1
# 4   16       0                0                    1                        1
#
#    preferred_offer_types  medium_of_operation  internet_option  \
# 0                      2                    1                0
# 1                      2                    0                2
# 2                      0                    3                1
# 3                      1                    2                2
# 4                      2                    1                1
#
#    days_since_last_login  avg_time_spent  ...  used_special_discount  \
# 0                     12          386.26  ...                      0
# 1                     11           37.80  ...                      0
# 2                     18          215.36  ...                      0
# 3                   -999           44.57  ...                      0
# 4                      6          349.88  ...                      1
#
#    offer_application_preference  past_complaint  complaint_status  day  month  \
# 0                             1               0                 0    2     11
# 1                             1               0                 0    1      3
# 2                             1               1                 3    3      3
# 3                             1               1                 4   18      8
# 4                             0               1                 3    5      5
#
#    year  minute  hour  sec
# 0  2015      19     7   30
# 1  2016      21    22   16
# 2  2017      40    16   39
# 3  2017      56    14   17
# 4  2015      57     2   53
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Train-Test splitting :

# %%
X_train=train.drop('churn_risk_score',1)
y_train=train['churn_risk_score']
X_test=test

# %%
X_train.shape,X_test.shape,y_train.shape
# Out:
# ((36992, 22), (19919, 22), (36992,))

# %% [markdown]
# #### P.S. we can change the feedback column too.Which I have missed previously.Following kernels will be using NLP to encode those features.

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re

# %%
paragraph=[]
for line in train_df['feedback']:
    paragraph.append(line)

# %%
paragraph
# Out:
# ['Products always in Stock',
#  'Quality Customer Care',
#  'Poor Website',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Website',
#  'Too many ads',
#  'Too many ads',
#  'Poor Customer Service',
#  'No reason specified',
#  'Products always in Stock',
#  'Poor Customer Service',
#  'Poor Website',
#  'User Friendly Website',
#  'No reason specified',
#  'Poor Website',
#  'Too many ads',
#  'No reason specified',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Website',
#  'Too many ads',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Website',
#  'User Friendly Website',
#  'No reason specified',
#  'User Friendly Website',
#  'Poor Product Quality',
#  'Poor Website',
#  'Reasonable Price',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Too many ads',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Product Quality',
#  'Quality Customer Care',
#  'No reason specified',
#  'Too many ads',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'Poor Product Quality',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'No reason specified',
#  'No reason specified',
#  'Poor Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Too many ads',
#  'No reason specified',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Product Quality',
#  'No reason specified',
#  'No reason specified',
#  'Products always in Stock',
#  'Poor Customer Service',
#  'Poor Website',
#  'No reason specified',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Website',
#  'Reasonable Price',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'No reason specified',
#  'No reason specified',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'Too many ads',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'User Friendly Website',
#  'Quality Customer Care',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'No reason specified',
#  'Products always in Stock',
#  'Products always in Stock',
#  'Products always in Stock',
#  'Too many ads',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'No reason specified',
#  'Too many ads',
#  'Too many ads',
#  'Poor Product Quality',
#  'Reasonable Price',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'No reason specified',
#  'Poor Website',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Website',
#  'User Friendly Website',
#  'Poor Website',
#  'Poor Product Quality',
#  'Too many ads',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Website',
#  'Products always in Stock',
#  'Too many ads',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Website',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Too many ads',
#  'User Friendly Website',
#  'Quality Customer Care',
#  'Products always in Stock',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Quality Customer Care',
#  'Too many ads',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Quality Customer Care',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'Quality Customer Care',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'Too many ads',
#  'Quality Customer Care',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Too many ads',
#  'Too many ads',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Customer Service',
#  'Too many ads',
#  'No reason specified',
#  'Quality Customer Care',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Website',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'User Friendly Website',
#  'Poor Website',
#  'No reason specified',
#  'Too many ads',
#  'Quality Customer Care',
#  'Poor Website',
#  'Too many ads',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Product Quality',
#  'No reason specified',
#  'Reasonable Price',
#  'Poor Website',
#  'Poor Customer Service',
#  'No reason specified',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Too many ads',
#  'No reason specified',
#  'No reason specified',
#  'No reason specified',
#  'Reasonable Price',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'No reason specified',
#  'Poor Product Quality',
#  'No reason specified',
#  'No reason specified',
#  'No reason specified',
#  'Too many ads',
#  'Too many ads',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'Too many ads',
#  'Poor Website',
#  'Poor Customer Service',
#  'No reason specified',
#  'Quality Customer Care',
#  'Reasonable Price',
#  'Too many ads',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Products always in Stock',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'No reason specified',
#  'Products always in Stock',
#  'No reason specified',
#  'User Friendly Website',
#  'Too many ads',
#  'Too many ads',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'No reason specified',
#  'Quality Customer Care',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Too many ads',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Quality Customer Care',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'No reason specified',
#  'Too many ads',
#  'Reasonable Price',
#  'Reasonable Price',
#  'Poor Customer Service',
#  'Poor Website',
#  'Products always in Stock',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'No reason specified',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'No reason specified',
#  'Too many ads',
#  'Quality Customer Care',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Too many ads',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'No reason specified',
#  'Too many ads',
#  'Products always in Stock',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Customer Service',
#  'Products always in Stock',
#  'Poor Website',
#  'Too many ads',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'No reason specified',
#  'Reasonable Price',
#  'Too many ads',
#  'Quality Customer Care',
#  'Too many ads',
#  'Too many ads',
#  'Poor Website',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Website',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'Reasonable Price',
#  'Too many ads',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Reasonable Price',
#  'No reason specified',
#  'Poor Product Quality',
#  'Products always in Stock',
#  'No reason specified',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Quality Customer Care',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Too many ads',
#  'Poor Product Quality',
#  'Reasonable Price',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'No reason specified',
#  'Too many ads',
#  'No reason specified',
#  'Quality Customer Care',
#  'User Friendly Website',
#  'Too many ads',
#  'Too many ads',
#  'Poor Website',
#  'Too many ads',
#  'Quality Customer Care',
#  'Too many ads',
#  'Poor Website',
#  'Quality Customer Care',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'No reason specified',
#  'Products always in Stock',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Website',
#  'Poor Website',
#  'Poor Website',
#  'Poor Website',
#  'Poor Website',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Poor Website',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'Poor Product Quality',
#  'No reason specified',
#  'User Friendly Website',
#  'Too many ads',
#  'Too many ads',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'No reason specified',
#  'Products always in Stock',
#  'Poor Customer Service',
#  'Poor Website',
#  'Too many ads',
#  'Too many ads',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Customer Service',
#  'Products always in Stock',
#  'Reasonable Price',
#  'Poor Customer Service',
#  'Too many ads',
#  'Too many ads',
#  'No reason specified',
#  'User Friendly Website',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Website',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Too many ads',
#  'Quality Customer Care',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Quality Customer Care',
#  'Poor Website',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Product Quality',
#  'Quality Customer Care',
#  'Reasonable Price',
#  'No reason specified',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Quality Customer Care',
#  'Poor Website',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'No reason specified',
#  'No reason specified',
#  'Too many ads',
#  'Poor Customer Service',
#  'Too many ads',
#  'Too many ads',
#  'No reason specified',
#  'Poor Product Quality',
#  'Too many ads',
#  'No reason specified',
#  'Too many ads',
#  'Poor Product Quality',
#  'Products always in Stock',
#  'No reason specified',
#  'No reason specified',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Products always in Stock',
#  'Reasonable Price',
#  'Poor Website',
#  'Poor Customer Service',
#  'Too many ads',
#  'Reasonable Price',
#  'Poor Website',
#  'Reasonable Price',
#  'Poor Customer Service',
#  'User Friendly Website',
#  'Poor Product Quality',
#  'Too many ads',
#  'User Friendly Website',
#  'Products always in Stock',
#  'Too many ads',
#  'Poor Website',
#  'No reason specified',
#  'Reasonable Price',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'User Friendly Website',
#  'Poor Website',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Products always in Stock',
#  'Quality Customer Care',
#  'User Friendly Website',
#  'Too many ads',
#  'Poor Website',
#  'Quality Customer Care',
#  'Reasonable Price',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Too many ads',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Too many ads',
#  'Reasonable Price',
#  'No reason specified',
#  'Reasonable Price',
#  'Products always in Stock',
#  'User Friendly Website',
#  'User Friendly Website',
#  'No reason specified',
#  'Poor Customer Service',
#  'User Friendly Website',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'No reason specified',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Reasonable Price',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Too many ads',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Products always in Stock',
#  'Too many ads',
#  'Too many ads',
#  'Too many ads',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Website',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'Poor Customer Service',
#  'No reason specified',
#  'Too many ads',
#  'No reason specified',
#  'Too many ads',
#  'Poor Website',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Website',
#  'Too many ads',
#  'Too many ads',
#  'User Friendly Website',
#  'Quality Customer Care',
#  'Poor Website',
#  'Poor Website',
#  'Quality Customer Care',
#  'No reason specified',
#  'No reason specified',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Product Quality',
#  'Too many ads',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'No reason specified',
#  'Products always in Stock',
#  'Products always in Stock',
#  'No reason specified',
#  'Poor Product Quality',
#  'No reason specified',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Reasonable Price',
#  'User Friendly Website',
#  'Poor Product Quality',
#  'Too many ads',
#  'Too many ads',
#  'Poor Customer Service',
#  'Too many ads',
#  'Poor Product Quality',
#  'No reason specified',
#  'No reason specified',
#  'No reason specified',
#  'Poor Customer Service',
#  'Too many ads',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'Poor Customer Service',
#  'Reasonable Price',
#  'Poor Website',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Website',
#  'Poor Product Quality',
#  'Too many ads',
#  'Quality Customer Care',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Website',
#  'Too many ads',
#  'Reasonable Price',
#  'Reasonable Price',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Website',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'User Friendly Website',
#  'Too many ads',
#  'Too many ads',
#  'Too many ads',
#  'Poor Website',
#  'No reason specified',
#  'No reason specified',
#  'No reason specified',
#  'Reasonable Price',
#  'User Friendly Website',
#  'Products always in Stock',
#  'User Friendly Website',
#  'No reason specified',
#  'Poor Website',
#  'No reason specified',
#  'Products always in Stock',
#  'Poor Website',
#  'Too many ads',
#  'Poor Website',
#  'No reason specified',
#  'Poor Website',
#  'Poor Website',
#  'No reason specified',
#  'Too many ads',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Website',
#  'Too many ads',
#  'Poor Product Quality',
#  'No reason specified',
#  'Too many ads',
#  'Poor Customer Service',
#  'Too many ads',
#  'Too many ads',
#  'Poor Customer Service',
#  'Too many ads',
#  'Too many ads',
#  'Poor Product Quality',
#  'No reason specified',
#  'User Friendly Website',
#  'No reason specified',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Too many ads',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Too many ads',
#  'No reason specified',
#  'Products always in Stock',
#  'Poor Website',
#  'Poor Product Quality',
#  'Quality Customer Care',
#  'Poor Website',
#  'Poor Product Quality',
#  'User Friendly Website',
#  'Poor Website',
#  'Poor Website',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Website',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Too many ads',
#  'Poor Website',
#  'Poor Website',
#  'Too many ads',
#  'Poor Website',
#  'Too many ads',
#  'No reason specified',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Website',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Customer Service',
#  'Products always in Stock',
#  'User Friendly Website',
#  'Reasonable Price',
#  'Poor Website',
#  'No reason specified',
#  'Too many ads',
#  'Too many ads',
#  'Too many ads',
#  'No reason specified',
#  'Too many ads',
#  'Products always in Stock',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Products always in Stock',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Website',
#  'User Friendly Website',
#  'Quality Customer Care',
#  'No reason specified',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Product Quality',
#  'Poor Website',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Products always in Stock',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'No reason specified',
#  'Poor Website',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Website',
#  'Poor Product Quality',
#  'Too many ads',
#  'Too many ads',
#  'Poor Product Quality',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'Poor Website',
#  'Reasonable Price',
#  'Too many ads',
#  'No reason specified',
#  'Poor Website',
#  'Too many ads',
#  'Poor Customer Service',
#  'Quality Customer Care',
#  'No reason specified',
#  'No reason specified',
#  'Poor Product Quality',
#  'Poor Website',
#  'Products always in Stock',
#  'Poor Customer Service',
#  'Poor Website',
#  'No reason specified',
#  'Poor Product Quality',
#  'No reason specified',
#  'Poor Website',
#  'Quality Customer Care',
#  'User Friendly Website',
#  'Poor Customer Service',
#  'Poor Customer Service',
#  'User Friendly Website',
#  'No reason specified',
#  'Poor Website',
#  'Reasonable Price',
#  'Poor Customer Service',
#  'Poor Product Quality',
#  'Poor Website',
#  'No reason specified',
#  'Quality Customer Care',
#  'Poor Product Quality',
#  'Quality Customer Care',
#  'Poor Customer Service',
#  'Poor Website',
#  ...]

# %%
wordnet=WordNetLemmatizer()

# %%
corpus=[]

for i in range(len(paragraph)):
    review=re.sub('[^a-zA-Z]',' ',paragraph[i])
    review=review.lower()
    review=review.split()
    review=[wordnet.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    review=' '.join(review)
    corpus.append(review)
    
corpus
# Out:
# ['product always stock',
#  'quality customer care',
#  'poor website',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'reason specified',
#  'product always stock',
#  'poor customer service',
#  'poor website',
#  'user friendly website',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'user friendly website',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'user friendly website',
#  'reason specified',
#  'user friendly website',
#  'poor product quality',
#  'poor website',
#  'reasonable price',
#  'many ad',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'product always stock',
#  'poor product quality',
#  'many ad',
#  'poor product quality',
#  'quality customer care',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'poor website',
#  'poor website',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'product always stock',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'product always stock',
#  'poor customer service',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'reasonable price',
#  'poor customer service',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'user friendly website',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'user friendly website',
#  'quality customer care',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'reason specified',
#  'product always stock',
#  'product always stock',
#  'product always stock',
#  'many ad',
#  'user friendly website',
#  'poor customer service',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'reasonable price',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'user friendly website',
#  'poor website',
#  'poor product quality',
#  'many ad',
#  'user friendly website',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'poor website',
#  'product always stock',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'poor product quality',
#  'user friendly website',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'user friendly website',
#  'quality customer care',
#  'product always stock',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'quality customer care',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'quality customer care',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'poor product quality',
#  'user friendly website',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'quality customer care',
#  'product always stock',
#  'poor product quality',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'quality customer care',
#  'poor customer service',
#  'poor customer service',
#  'reasonable price',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'quality customer care',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'user friendly website',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'quality customer care',
#  'poor website',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'reasonable price',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'many ad',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'user friendly website',
#  'many ad',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'reasonable price',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'quality customer care',
#  'reasonable price',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'product always stock',
#  'reason specified',
#  'user friendly website',
#  'many ad',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'quality customer care',
#  'poor product quality',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'quality customer care',
#  'reasonable price',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'reasonable price',
#  'reasonable price',
#  'poor customer service',
#  'poor website',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'user friendly website',
#  'reason specified',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'quality customer care',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'reasonable price',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'reasonable price',
#  'poor product quality',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'user friendly website',
#  'many ad',
#  'poor website',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'many ad',
#  'product always stock',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'product always stock',
#  'poor website',
#  'many ad',
#  'user friendly website',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'reasonable price',
#  'many ad',
#  'quality customer care',
#  'many ad',
#  'many ad',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'reasonable price',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'poor customer service',
#  'reasonable price',
#  'reasonable price',
#  'reason specified',
#  'poor product quality',
#  'product always stock',
#  'reason specified',
#  'poor website',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'quality customer care',
#  'poor customer service',
#  'poor product quality',
#  'user friendly website',
#  'many ad',
#  'poor product quality',
#  'reasonable price',
#  'user friendly website',
#  'poor customer service',
#  'user friendly website',
#  'poor customer service',
#  'poor customer service',
#  'reasonable price',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'quality customer care',
#  'user friendly website',
#  'many ad',
#  'many ad',
#  'poor website',
#  'many ad',
#  'quality customer care',
#  'many ad',
#  'poor website',
#  'quality customer care',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'product always stock',
#  'poor customer service',
#  'reasonable price',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'poor website',
#  'poor website',
#  'poor website',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'product always stock',
#  'poor product quality',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'user friendly website',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'user friendly website',
#  'reason specified',
#  'product always stock',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'reasonable price',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'product always stock',
#  'reasonable price',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'user friendly website',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'quality customer care',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'quality customer care',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'quality customer care',
#  'reasonable price',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'quality customer care',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'product always stock',
#  'reason specified',
#  'reason specified',
#  'user friendly website',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'product always stock',
#  'reasonable price',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'reasonable price',
#  'poor website',
#  'reasonable price',
#  'poor customer service',
#  'user friendly website',
#  'poor product quality',
#  'many ad',
#  'user friendly website',
#  'product always stock',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'reasonable price',
#  'reasonable price',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'user friendly website',
#  'poor website',
#  'reason specified',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'reasonable price',
#  'poor product quality',
#  'product always stock',
#  'quality customer care',
#  'user friendly website',
#  'many ad',
#  'poor website',
#  'quality customer care',
#  'reasonable price',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'user friendly website',
#  'many ad',
#  'reasonable price',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'many ad',
#  'reasonable price',
#  'reason specified',
#  'reasonable price',
#  'product always stock',
#  'user friendly website',
#  'user friendly website',
#  'reason specified',
#  'poor customer service',
#  'user friendly website',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'reasonable price',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'many ad',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'reasonable price',
#  'product always stock',
#  'many ad',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'many ad',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'poor website',
#  'product always stock',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'many ad',
#  'many ad',
#  'user friendly website',
#  'quality customer care',
#  'poor website',
#  'poor website',
#  'quality customer care',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'reasonable price',
#  'poor website',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'reason specified',
#  'product always stock',
#  'product always stock',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'reasonable price',
#  'user friendly website',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'product always stock',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'reasonable price',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'poor product quality',
#  'many ad',
#  'quality customer care',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'many ad',
#  'reasonable price',
#  'reasonable price',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'user friendly website',
#  'many ad',
#  'many ad',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'reasonable price',
#  'user friendly website',
#  'product always stock',
#  'user friendly website',
#  'reason specified',
#  'poor website',
#  'reason specified',
#  'product always stock',
#  'poor website',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'reason specified',
#  'user friendly website',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'product always stock',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'product always stock',
#  'poor website',
#  'poor product quality',
#  'quality customer care',
#  'poor website',
#  'poor product quality',
#  'user friendly website',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'poor website',
#  'many ad',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'product always stock',
#  'user friendly website',
#  'reasonable price',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'product always stock',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'product always stock',
#  'poor product quality',
#  'poor website',
#  'poor website',
#  'user friendly website',
#  'quality customer care',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'reasonable price',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'quality customer care',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'product always stock',
#  'poor customer service',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'quality customer care',
#  'user friendly website',
#  'poor customer service',
#  'poor customer service',
#  'user friendly website',
#  'reason specified',
#  'poor website',
#  'reasonable price',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'quality customer care',
#  'poor product quality',
#  'quality customer care',
#  'poor customer service',
#  'poor website',
#  ...]

# %%
xx=pd.DataFrame(corpus)

# %%
xx.columns=['name']

# %%
xx.head()
# Out:
#                     name
# 0   product always stock
# 1  quality customer care
# 2           poor website
# 3           poor website
# 4           poor website

# %%
xx['name'].nunique()
# Out:
# 9

# %%
feedback=xx['name'].unique()
feedback
# Out:
# array(['product always stock', 'quality customer care', 'poor website',
#        'reason specified', 'poor product quality',
#        'poor customer service', 'many ad', 'user friendly website',
#        'reasonable price'], dtype=object)

# %%
for i in range(9):
    xx.replace(feedback[i],i,inplace=True)
xx.head()
# Out:
#    name
# 0     0
# 1     1
# 2     2
# 3     2
# 4     2

# %%
df1=pd.DataFrame({'1':xx['name'],'2':train_df['feedback']})
df1.head(15)
# Out:
#     1                         2
# 0   0  Products always in Stock
# 1   1     Quality Customer Care
# 2   2              Poor Website
# 3   2              Poor Website
# 4   2              Poor Website
# 5   3       No reason specified
# 6   3       No reason specified
# 7   4      Poor Product Quality
# 8   5     Poor Customer Service
# 9   5     Poor Customer Service
# 10  4      Poor Product Quality
# 11  6              Too many ads
# 12  5     Poor Customer Service
# 13  4      Poor Product Quality
# 14  2              Poor Website

# %%
X_train['feedback']=xx['name']

# %%
paragraph=[]
for line in test_df['feedback']:
    paragraph.append(line)

# %%
corpus=[]

for i in range(len(paragraph)):
    review=re.sub('[^a-zA-Z]',' ',paragraph[i])
    review=review.lower()
    review=review.split()
    review=[wordnet.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    review=' '.join(review)
    corpus.append(review)
    
corpus
# Out:
# ['poor product quality',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'poor website',
#  'poor product quality',
#  'reasonable price',
#  'many ad',
#  'many ad',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'poor product quality',
#  'user friendly website',
#  'reason specified',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'user friendly website',
#  'poor website',
#  'reasonable price',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'reasonable price',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor website',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'user friendly website',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'reason specified',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'reasonable price',
#  'poor customer service',
#  'many ad',
#  'poor customer service',
#  'reasonable price',
#  'reason specified',
#  'quality customer care',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'reasonable price',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'product always stock',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'user friendly website',
#  'user friendly website',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'reasonable price',
#  'reasonable price',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'poor website',
#  'reasonable price',
#  'reason specified',
#  'poor product quality',
#  'quality customer care',
#  'poor website',
#  'poor customer service',
#  'product always stock',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'user friendly website',
#  'reason specified',
#  'poor customer service',
#  'reasonable price',
#  'many ad',
#  'user friendly website',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'quality customer care',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'quality customer care',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor product quality',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'user friendly website',
#  'reason specified',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'many ad',
#  'user friendly website',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'reasonable price',
#  'reason specified',
#  'quality customer care',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'reasonable price',
#  'many ad',
#  'poor website',
#  'many ad',
#  'poor website',
#  'poor website',
#  'many ad',
#  'product always stock',
#  'poor website',
#  'user friendly website',
#  'poor customer service',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'reasonable price',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'quality customer care',
#  'quality customer care',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'many ad',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'quality customer care',
#  'poor product quality',
#  'reasonable price',
#  'poor customer service',
#  'quality customer care',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'poor website',
#  'product always stock',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'user friendly website',
#  'user friendly website',
#  'poor website',
#  'reason specified',
#  'reasonable price',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'product always stock',
#  'poor customer service',
#  'product always stock',
#  'poor website',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'reasonable price',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'quality customer care',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'reasonable price',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'quality customer care',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'user friendly website',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor website',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'reason specified',
#  'user friendly website',
#  'reasonable price',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'many ad',
#  'product always stock',
#  'many ad',
#  'poor product quality',
#  'quality customer care',
#  'poor customer service',
#  'reason specified',
#  'reason specified',
#  'user friendly website',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'many ad',
#  'reasonable price',
#  'reason specified',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'poor customer service',
#  'poor customer service',
#  'user friendly website',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'poor product quality',
#  'product always stock',
#  'reason specified',
#  'quality customer care',
#  'many ad',
#  'poor customer service',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'product always stock',
#  'poor customer service',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'reasonable price',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'product always stock',
#  'poor customer service',
#  'user friendly website',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'product always stock',
#  'many ad',
#  'quality customer care',
#  'reason specified',
#  'poor website',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'product always stock',
#  'poor customer service',
#  'product always stock',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'user friendly website',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'reasonable price',
#  'reason specified',
#  'user friendly website',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'quality customer care',
#  'quality customer care',
#  'poor customer service',
#  'reasonable price',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'poor customer service',
#  'reason specified',
#  'reasonable price',
#  'reasonable price',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'quality customer care',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'quality customer care',
#  'many ad',
#  'many ad',
#  'poor product quality',
#  'reasonable price',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'product always stock',
#  'reasonable price',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'user friendly website',
#  'many ad',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'reasonable price',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'quality customer care',
#  'reason specified',
#  'poor product quality',
#  'product always stock',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'user friendly website',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'quality customer care',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'product always stock',
#  'many ad',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'quality customer care',
#  'poor website',
#  'poor website',
#  'poor website',
#  'many ad',
#  'poor website',
#  'product always stock',
#  'product always stock',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'poor website',
#  'reason specified',
#  'reasonable price',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'product always stock',
#  'quality customer care',
#  'poor product quality',
#  'reasonable price',
#  'many ad',
#  'reasonable price',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'many ad',
#  'user friendly website',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'reasonable price',
#  'product always stock',
#  'poor website',
#  'poor product quality',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'quality customer care',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'poor product quality',
#  'quality customer care',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'reasonable price',
#  'quality customer care',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'user friendly website',
#  'poor customer service',
#  'poor customer service',
#  'reasonable price',
#  'poor customer service',
#  'many ad',
#  'many ad',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'product always stock',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'poor product quality',
#  'reason specified',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'quality customer care',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'reasonable price',
#  'poor website',
#  'reason specified',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'reasonable price',
#  'many ad',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'quality customer care',
#  'poor product quality',
#  'reason specified',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'product always stock',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'reasonable price',
#  'poor customer service',
#  'many ad',
#  'poor customer service',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'user friendly website',
#  'many ad',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'poor website',
#  'poor customer service',
#  'poor customer service',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'poor customer service',
#  'poor website',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'reasonable price',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'user friendly website',
#  'poor product quality',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'many ad',
#  'many ad',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'quality customer care',
#  'poor website',
#  'many ad',
#  'poor product quality',
#  'many ad',
#  'poor website',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'reason specified',
#  'many ad',
#  'poor website',
#  'product always stock',
#  'reason specified',
#  'many ad',
#  'poor customer service',
#  'poor website',
#  'product always stock',
#  'many ad',
#  'poor customer service',
#  'reasonable price',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'poor customer service',
#  'poor website',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'user friendly website',
#  'poor customer service',
#  'reason specified',
#  'many ad',
#  'poor product quality',
#  'poor customer service',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'reasonable price',
#  'many ad',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'many ad',
#  'poor product quality',
#  'poor product quality',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'reasonable price',
#  'poor website',
#  'product always stock',
#  'product always stock',
#  'poor customer service',
#  'many ad',
#  'reason specified',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'many ad',
#  'poor customer service',
#  'reason specified',
#  'poor customer service',
#  'poor website',
#  'poor website',
#  'quality customer care',
#  'many ad',
#  'reason specified',
#  'poor customer service',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'user friendly website',
#  'user friendly website',
#  'poor customer service',
#  'poor website',
#  'many ad',
#  'poor website',
#  'poor customer service',
#  'poor product quality',
#  'poor customer service',
#  'quality customer care',
#  'poor customer service',
#  'reasonable price',
#  'poor customer service',
#  'poor website',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'poor product quality',
#  'poor website',
#  'product always stock',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'many ad',
#  'many ad',
#  'quality customer care',
#  'quality customer care',
#  'poor website',
#  'poor product quality',
#  'poor website',
#  'poor product quality',
#  'many ad',
#  'reason specified',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'poor product quality',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'reason specified',
#  'reason specified',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'product always stock',
#  'quality customer care',
#  'reason specified',
#  'poor customer service',
#  'many ad',
#  'poor website',
#  'reason specified',
#  'poor customer service',
#  'poor product quality',
#  'reasonable price',
#  'poor product quality',
#  'many ad',
#  'reasonable price',
#  'poor website',
#  'poor website',
#  'user friendly website',
#  'reason specified',
#  'many ad',
#  'reason specified',
#  'poor website',
#  'many ad',
#  'reason specified',
#  'reason specified',
#  'poor product quality',
#  'product always stock',
#  'poor website',
#  'poor customer service',
#  'product always stock',
#  'poor customer service',
#  'poor product quality',
#  'poor website',
#  'poor customer service',
#  'reason specified',
#  'poor product quality',
#  ...]

# %%
xx=pd.DataFrame({'name':corpus})

# %%
for i in range(9):
    xx.replace(feedback[i],i,inplace=True)
xx.head()
# Out:
#    name
# 0     4
# 1     2
# 2     3
# 3     6
# 4     2

# %%
df1=pd.DataFrame({'1':xx['name'],'2':test_df['feedback']})
df1.head(15)
# Out:
#     1                      2
# 0   4   Poor Product Quality
# 1   2           Poor Website
# 2   3    No reason specified
# 3   6           Too many ads
# 4   2           Poor Website
# 5   4   Poor Product Quality
# 6   8       Reasonable Price
# 7   6           Too many ads
# 8   6           Too many ads
# 9   2           Poor Website
# 10  4   Poor Product Quality
# 11  3    No reason specified
# 12  2           Poor Website
# 13  5  Poor Customer Service
# 14  2           Poor Website

# %%
X_test['feedback']=xx['name']

# %%
X_train.head()
# Out:
#    age  gender  region_category  membership_category  joined_through_referral  \
# 0   18       0                3                    5                        0
# 1   32       0                1                    4                        2
# 2   44       0                0                    1                        1
# 3   37       1                1                    1                        1
# 4   31       0                1                    1                        0
#
#    preferred_offer_types  medium_of_operation  internet_option  \
# 0                      0                    2                0
# 1                      0                    0                1
# 2                      0                    0                0
# 3                      0                    0                1
# 4                      1                    1                1
#
#    days_since_last_login  avg_time_spent  ...  offer_application_preference  \
# 0                     17          300.63  ...                             0
# 1                     16          306.34  ...                             1
# 2                     14          516.16  ...                             0
# 3                     11           53.27  ...                             0
# 4                     20          113.13  ...                             0
#
#    past_complaint  complaint_status  day  month  year  minute  hour  sec  \
# 0               0                 0   17      8  2017       8    16    2
# 1               1                 2   28      8  2017      38    12   13
# 2               1                 3   11     11  2016      53    22   21
# 3               1                 1   29     10  2016      57    15   50
# 4               1                 2   12      9  2017      46    15   44
#
#    feedback
# 0         0
# 1         1
# 2         2
# 3         2
# 4         2
#
# [5 rows x 23 columns]

# %%
X_test.head()
# Out:
#    age  gender  region_category  membership_category  joined_through_referral  \
# 0   50       0                3                    4                        0
# 1   41       1                3                    2                        0
# 2   31       0                0                    3                        0
# 3   64       1                0                    3                        1
# 4   16       0                0                    1                        1
#
#    preferred_offer_types  medium_of_operation  internet_option  \
# 0                      2                    1                0
# 1                      2                    0                2
# 2                      0                    3                1
# 3                      1                    2                2
# 4                      2                    1                1
#
#    days_since_last_login  avg_time_spent  ...  offer_application_preference  \
# 0                     12          386.26  ...                             1
# 1                     11           37.80  ...                             1
# 2                     18          215.36  ...                             1
# 3                   -999           44.57  ...                             1
# 4                      6          349.88  ...                             0
#
#    past_complaint  complaint_status  day  month  year  minute  hour  sec  \
# 0               0                 0    2     11  2015      19     7   30
# 1               0                 0    1      3  2016      21    22   16
# 2               1                 3    3      3  2017      40    16   39
# 3               1                 4   18      8  2017      56    14   17
# 4               1                 3    5      5  2015      57     2   53
#
#    feedback
# 0         4
# 1         2
# 2         3
# 3         6
# 4         2
#
# [5 rows x 23 columns]

# %% [markdown]
# Basically what we did here is lemmatize every sentences and then encoded them.

# %% [markdown]
# # Data Prediction :
#
# Now we are goinf to predict the dataset using two type of classifiers.
#
#
# 1. RandomForestClassifier    ( from sklearn.ensemble )
# 2. CatBoostClassifier        ( from catboost )

# %%
train_1=pd.concat([X_train,train_df['churn_risk_score']],axis=1)
train_1.head()
# Out:
#    age  gender  region_category  membership_category  joined_through_referral  \
# 0   18       0                3                    5                        0
# 1   32       0                1                    4                        2
# 2   44       0                0                    1                        1
# 3   37       1                1                    1                        1
# 4   31       0                1                    1                        0
#
#    preferred_offer_types  medium_of_operation  internet_option  \
# 0                      0                    2                0
# 1                      0                    0                1
# 2                      0                    0                0
# 3                      0                    0                1
# 4                      1                    1                1
#
#    days_since_last_login  avg_time_spent  ...  past_complaint  \
# 0                     17          300.63  ...               0
# 1                     16          306.34  ...               1
# 2                     14          516.16  ...               1
# 3                     11           53.27  ...               1
# 4                     20          113.13  ...               1
#
#    complaint_status  day  month  year  minute  hour  sec  feedback  \
# 0                 0   17      8  2017       8    16    2         0
# 1                 2   28      8  2017      38    12   13         1
# 2                 3   11     11  2016      53    22   21         2
# 3                 1   29     10  2016      57    15   50         2
# 4                 2   12      9  2017      46    15   44         2
#
#    churn_risk_score
# 0                 2
# 1                 1
# 2                 5
# 3                 5
# 4                 5
#
# [5 rows x 24 columns]

# %%
def create_submission(test,model,file_name):
    y_pred=model.predict(X_test)
    y_pred=y_pred.reshape(y_pred.shape[0])
    y_pred=y_pred.tolist()
    subs=pd.DataFrame({'customer_id':test_df['customer_id'],'churn_risk_score':y_pred})
    subs.to_csv('file_name',index=False)
    
    
    
def train_model(epochs,df,model):
    for i in range(epochs):
        print('Epoch ',i+1,' initiated................................')
        func=model
        df=train_1.sample(frac=0.8)
        x_train=df.drop('churn_risk_score',1)
        y_train=df['churn_risk_score']
        func.fit(x_train,y_train)
        print('Accuracy over this random data : ',func.score(x_train,y_train) )
    return model

# %%
X_test.head()
# Out:
#    age  gender  region_category  membership_category  joined_through_referral  \
# 0   50       0                3                    4                        0
# 1   41       1                3                    2                        0
# 2   31       0                0                    3                        0
# 3   64       1                0                    3                        1
# 4   16       0                0                    1                        1
#
#    preferred_offer_types  medium_of_operation  internet_option  \
# 0                      2                    1                0
# 1                      2                    0                2
# 2                      0                    3                1
# 3                      1                    2                2
# 4                      2                    1                1
#
#    days_since_last_login  avg_time_spent  ...  offer_application_preference  \
# 0                     12          386.26  ...                             1
# 1                     11           37.80  ...                             1
# 2                     18          215.36  ...                             1
# 3                   -999           44.57  ...                             1
# 4                      6          349.88  ...                             0
#
#    past_complaint  complaint_status  day  month  year  minute  hour  sec  \
# 0               0                 0    2     11  2015      19     7   30
# 1               0                 0    1      3  2016      21    22   16
# 2               1                 3    3      3  2017      40    16   39
# 3               1                 4   18      8  2017      56    14   17
# 4               1                 3    5      5  2015      57     2   53
#
#    feedback
# 0         4
# 1         2
# 2         3
# 3         6
# 4         2
#
# [5 rows x 23 columns]

# %%
from catboost import CatBoostClassifier as cbtc
from sklearn.ensemble import RandomForestClassifier as rfc

# %% [markdown]
# Now we have used catboost over the train and test data.Lets see what accuracy we cam achieve.

# %% [markdown]
# After checking for hours we have taken selected features in our dataset , so that it may predict the best solution.

# %%
df1=X_train.drop(labels=['joined_through_referral','year','month' ,  'minute', 'sec',],axis=1)
df2=X_test.drop(labels=['joined_through_referral','year', 'month', 'minute', 'sec',],axis=1)

# %%
model=cbtc(verbose=0)
model.fit(df1,y_train)
print(model.score(df1,y_train))
# Out:
# 0.8898951124567474

# %%
model=cbtc()
model.fit(df1,y_train)
print(model.score(df1,y_train))
y_pred=model.predict(df2)
y_pred=y_pred.reshape(y_pred.shape[0])
y_pred=y_pred.tolist()
subs=pd.DataFrame({'customer_id':test_df['customer_id'][:10],'churn_risk_score':y_pred[:10]})
subs.to_csv('submission_catboost.csv',index=False)
# Out:
# Learning rate set to 0.095125
# 0:	learn: 1.5501898	total: 37.5ms	remaining: 37.4s
# 1:	learn: 1.3880319	total: 65.5ms	remaining: 32.7s
# 2:	learn: 1.2705457	total: 92.1ms	remaining: 30.6s
# 3:	learn: 1.1655267	total: 118ms	remaining: 29.4s
# 4:	learn: 1.0868804	total: 145ms	remaining: 28.8s
# 5:	learn: 1.0166021	total: 173ms	remaining: 28.6s
# 6:	learn: 0.9598743	total: 204ms	remaining: 28.9s
# 7:	learn: 0.9088928	total: 233ms	remaining: 28.8s
# 8:	learn: 0.8656810	total: 264ms	remaining: 29.1s
# 9:	learn: 0.8271171	total: 291ms	remaining: 28.9s
# 10:	learn: 0.7976041	total: 318ms	remaining: 28.6s
# 249:	learn: 0.4418861	total: 6.96s	remaining: 20.9s
# 250:	learn: 0.4416700	total: 7s	remaining: 20.9s
# 251:	learn: 0.4414428	total: 7.03s	remaining: 20.9s
# 252:	learn: 0.4412380	total: 7.05s	remaining: 20.8s
# 253:	learn: 0.4410744	total: 7.08s	remaining: 20.8s
# 254:	learn: 0.4407319	total: 7.11s	remaining: 20.8s
# 255:	learn: 0.4405045	total: 7.14s	remaining: 20.7s
# 256:	learn: 0.4402834	total: 7.17s	remaining: 20.7s
# 257:	learn: 0.4400696	total: 7.21s	remaining: 20.7s
# 258:	learn: 0.4399705	total: 7.24s	remaining: 20.7s
# 259:	learn: 0.4398470	total: 7.26s	remaining: 20.7s
# 260:	learn: 0.4396294	total: 7.29s	remaining: 20.6s
# 261:	learn: 0.4394481	total: 7.32s	remaining: 20.6s
# 262:	learn: 0.4391841	total: 7.35s	remaining: 20.6s
# 263:	learn: 0.4389525	total: 7.38s	remaining: 20.6s
# 264:	learn: 0.4387643	total: 7.41s	remaining: 20.5s
# 265:	learn: 0.4386478	total: 7.43s	remaining: 20.5s
# 266:	learn: 0.4385818	total: 7.46s	remaining: 20.5s
# 267:	learn: 0.4384973	total: 7.49s	remaining: 20.4s
# 268:	learn: 0.4382812	total: 7.51s	remaining: 20.4s
# 269:	learn: 0.4381756	total: 7.54s	remaining: 20.4s
# 270:	learn: 0.4380269	total: 7.57s	remaining: 20.4s
# 271:	learn: 0.4378981	total: 7.59s	remaining: 20.3s
# 272:	learn: 0.4376053	total: 7.62s	remaining: 20.3s
# 273:	learn: 0.4372764	total: 7.65s	remaining: 20.3s
# 274:	learn: 0.4371160	total: 7.68s	remaining: 20.3s
# 275:	learn: 0.4368966	total: 7.71s	remaining: 20.2s
# 276:	learn: 0.4366394	total: 7.74s	remaining: 20.2s
# 277:	learn: 0.4364849	total: 7.76s	remaining: 20.2s
# 278:	learn: 0.4363401	total: 7.79s	remaining: 20.1s
# 279:	learn: 0.4359959	total: 7.82s	remaining: 20.1s
# 280:	learn: 0.4358718	total: 7.85s	remaining: 20.1s
# 281:	learn: 0.4356737	total: 7.88s	remaining: 20.1s
# 282:	learn: 0.4355112	total: 7.91s	remaining: 20s
# 283:	learn: 0.4352652	total: 7.94s	remaining: 20s
# 284:	learn: 0.4351039	total: 7.97s	remaining: 20s
# 285:	learn: 0.4349180	total: 8s	remaining: 20s
# 286:	learn: 0.4347795	total: 8.03s	remaining: 19.9s
# 287:	learn: 0.4345001	total: 8.05s	remaining: 19.9s
# 288:	learn: 0.4343421	total: 8.08s	remaining: 19.9s
# 289:	learn: 0.4342498	total: 8.1s	remaining: 19.8s
# 290:	learn: 0.4340026	total: 8.13s	remaining: 19.8s
# 291:	learn: 0.4337909	total: 8.16s	remaining: 19.8s
# 292:	learn: 0.4335835	total: 8.19s	remaining: 19.8s
# 293:	learn: 0.4334690	total: 8.21s	remaining: 19.7s
# 294:	learn: 0.4332906	total: 8.24s	remaining: 19.7s
# 295:	learn: 0.4330810	total: 8.27s	remaining: 19.7s
# 677:	learn: 0.3755646	total: 19s	remaining: 9.04s
# 678:	learn: 0.3754887	total: 19.1s	remaining: 9.02s
# 679:	learn: 0.3752858	total: 19.1s	remaining: 8.99s
# 680:	learn: 0.3751901	total: 19.1s	remaining: 8.96s
# 681:	learn: 0.3750287	total: 19.1s	remaining: 8.93s
# 682:	learn: 0.3748362	total: 19.2s	remaining: 8.9s
# 683:	learn: 0.3746741	total: 19.2s	remaining: 8.87s
# 684:	learn: 0.3745701	total: 19.2s	remaining: 8.84s
# 685:	learn: 0.3743836	total: 19.3s	remaining: 8.82s
# 686:	learn: 0.3743057	total: 19.3s	remaining: 8.79s
# 687:	learn: 0.3741394	total: 19.3s	remaining: 8.76s
# 688:	learn: 0.3740084	total: 19.4s	remaining: 8.73s
# 689:	learn: 0.3738712	total: 19.4s	remaining: 8.71s
# 690:	learn: 0.3737389	total: 19.4s	remaining: 8.68s
# 691:	learn: 0.3736003	total: 19.4s	remaining: 8.65s
# 692:	learn: 0.3734244	total: 19.5s	remaining: 8.62s
# 693:	learn: 0.3732419	total: 19.5s	remaining: 8.59s
# 694:	learn: 0.3731709	total: 19.5s	remaining: 8.57s
# 695:	learn: 0.3730831	total: 19.5s	remaining: 8.54s
# 696:	learn: 0.3729265	total: 19.6s	remaining: 8.51s
# 697:	learn: 0.3728517	total: 19.6s	remaining: 8.48s
# 698:	learn: 0.3726967	total: 19.6s	remaining: 8.46s
# 699:	learn: 0.3725657	total: 19.7s	remaining: 8.43s
# 700:	learn: 0.3723472	total: 19.7s	remaining: 8.4s
# 701:	learn: 0.3722125	total: 19.7s	remaining: 8.37s
# 702:	learn: 0.3721433	total: 19.7s	remaining: 8.34s
# 703:	learn: 0.3720328	total: 19.8s	remaining: 8.31s
# 704:	learn: 0.3718577	total: 19.8s	remaining: 8.28s
# 705:	learn: 0.3717401	total: 19.8s	remaining: 8.26s
# 706:	learn: 0.3716069	total: 19.9s	remaining: 8.24s
# 707:	learn: 0.3715390	total: 19.9s	remaining: 8.21s
# 708:	learn: 0.3714067	total: 20s	remaining: 8.19s
# 709:	learn: 0.3713340	total: 20s	remaining: 8.17s
# 710:	learn: 0.3712068	total: 20s	remaining: 8.15s
# 711:	learn: 0.3710979	total: 20.1s	remaining: 8.12s
# 712:	learn: 0.3709509	total: 20.1s	remaining: 8.09s
# 713:	learn: 0.3708609	total: 20.1s	remaining: 8.06s
# 714:	learn: 0.3707890	total: 20.2s	remaining: 8.03s
# 715:	learn: 0.3707193	total: 20.2s	remaining: 8.01s
# 716:	learn: 0.3706068	total: 20.2s	remaining: 7.98s
# 717:	learn: 0.3704913	total: 20.3s	remaining: 7.96s
# 718:	learn: 0.3703284	total: 20.3s	remaining: 7.93s
# 719:	learn: 0.3702474	total: 20.3s	remaining: 7.9s
# 720:	learn: 0.3701628	total: 20.3s	remaining: 7.87s
# 721:	learn: 0.3700589	total: 20.4s	remaining: 7.84s
# 722:	learn: 0.3698773	total: 20.4s	remaining: 7.81s
# 723:	learn: 0.3697295	total: 20.4s	remaining: 7.79s
# 724:	learn: 0.3696110	total: 20.5s	remaining: 7.76s
# 725:	learn: 0.3694746	total: 20.5s	remaining: 7.73s
# 726:	learn: 0.3693985	total: 20.5s	remaining: 7.7s
# 727:	learn: 0.3693114	total: 20.5s	remaining: 7.67s
# 728:	learn: 0.3692535	total: 20.6s	remaining: 7.64s
# 729:	learn: 0.3691403	total: 20.6s	remaining: 7.62s
# 730:	learn: 0.3689945	total: 20.6s	remaining: 7.59s
# 731:	learn: 0.3688466	total: 20.7s	remaining: 7.56s
# 732:	learn: 0.3686722	total: 20.7s	remaining: 7.53s
# 733:	learn: 0.3685255	total: 20.7s	remaining: 7.5s
# 734:	learn: 0.3684369	total: 20.7s	remaining: 7.47s
# 735:	learn: 0.3683549	total: 20.8s	remaining: 7.45s
# 736:	learn: 0.3682630	total: 20.8s	remaining: 7.42s
# 737:	learn: 0.3681998	total: 20.8s	remaining: 7.39s
# 738:	learn: 0.3680797	total: 20.8s	remaining: 7.36s
# 739:	learn: 0.3679593	total: 20.9s	remaining: 7.33s
# 740:	learn: 0.3678501	total: 20.9s	remaining: 7.31s
# 741:	learn: 0.3677545	total: 20.9s	remaining: 7.28s
# 742:	learn: 0.3675616	total: 21s	remaining: 7.25s
# 743:	learn: 0.3674697	total: 21s	remaining: 7.22s
# 744:	learn: 0.3673290	total: 21s	remaining: 7.19s
# 745:	learn: 0.3672616	total: 21s	remaining: 7.17s
# 746:	learn: 0.3670868	total: 21.1s	remaining: 7.14s
# 747:	learn: 0.3668946	total: 21.1s	remaining: 7.11s
# 748:	learn: 0.3667781	total: 21.1s	remaining: 7.08s
# 749:	learn: 0.3666932	total: 21.2s	remaining: 7.05s
# 750:	learn: 0.3665729	total: 21.2s	remaining: 7.03s
# 751:	learn: 0.3664196	total: 21.2s	remaining: 7s
# 752:	learn: 0.3663443	total: 21.2s	remaining: 6.97s
# 753:	learn: 0.3662636	total: 21.3s	remaining: 6.94s
# 754:	learn: 0.3660979	total: 21.3s	remaining: 6.91s
# 755:	learn: 0.3659148	total: 21.3s	remaining: 6.88s
# 756:	learn: 0.3657702	total: 21.4s	remaining: 6.86s
# 757:	learn: 0.3656230	total: 21.4s	remaining: 6.83s
# 758:	learn: 0.3654085	total: 21.4s	remaining: 6.8s
# 759:	learn: 0.3652899	total: 21.4s	remaining: 6.77s
# 760:	learn: 0.3651689	total: 21.5s	remaining: 6.74s
# 761:	learn: 0.3650858	total: 21.5s	remaining: 6.71s
# 762:	learn: 0.3648605	total: 21.5s	remaining: 6.69s
# 763:	learn: 0.3646977	total: 21.6s	remaining: 6.66s
# 764:	learn: 0.3645447	total: 21.6s	remaining: 6.63s
# 765:	learn: 0.3643222	total: 21.6s	remaining: 6.6s
# 766:	learn: 0.3641726	total: 21.6s	remaining: 6.58s
# 767:	learn: 0.3640907	total: 21.7s	remaining: 6.54s
# 768:	learn: 0.3639322	total: 21.7s	remaining: 6.52s
# 769:	learn: 0.3637635	total: 21.7s	remaining: 6.49s
# 770:	learn: 0.3635028	total: 21.8s	remaining: 6.46s
# 913:	learn: 0.3455977	total: 25.8s	remaining: 2.43s
# 914:	learn: 0.3454774	total: 25.8s	remaining: 2.4s
# 915:	learn: 0.3453134	total: 25.9s	remaining: 2.37s
# 916:	learn: 0.3451996	total: 25.9s	remaining: 2.34s
# 917:	learn: 0.3451177	total: 25.9s	remaining: 2.31s
# 918:	learn: 0.3449580	total: 25.9s	remaining: 2.29s
# 919:	learn: 0.3448868	total: 26s	remaining: 2.26s
# 920:	learn: 0.3448120	total: 26s	remaining: 2.23s
# 921:	learn: 0.3447181	total: 26s	remaining: 2.2s
# 922:	learn: 0.3446288	total: 26s	remaining: 2.17s
# 923:	learn: 0.3445906	total: 26.1s	remaining: 2.14s
# 924:	learn: 0.3443967	total: 26.1s	remaining: 2.12s
# 925:	learn: 0.3442468	total: 26.1s	remaining: 2.09s
# 926:	learn: 0.3441420	total: 26.2s	remaining: 2.06s
# 927:	learn: 0.3439843	total: 26.2s	remaining: 2.03s
# 928:	learn: 0.3438684	total: 26.2s	remaining: 2s
# 929:	learn: 0.3436378	total: 26.2s	remaining: 1.98s
# 930:	learn: 0.3435169	total: 26.3s	remaining: 1.95s
# 931:	learn: 0.3432962	total: 26.3s	remaining: 1.92s
# 932:	learn: 0.3431635	total: 26.3s	remaining: 1.89s
# 933:	learn: 0.3430390	total: 26.4s	remaining: 1.86s
# 934:	learn: 0.3428570	total: 26.4s	remaining: 1.83s
# 935:	learn: 0.3427562	total: 26.4s	remaining: 1.8s
# 936:	learn: 0.3425993	total: 26.4s	remaining: 1.78s
# 937:	learn: 0.3425077	total: 26.5s	remaining: 1.75s
# 938:	learn: 0.3424275	total: 26.5s	remaining: 1.72s
# 939:	learn: 0.3423009	total: 26.5s	remaining: 1.69s
# 940:	learn: 0.3422065	total: 26.5s	remaining: 1.66s
# 941:	learn: 0.3421027	total: 26.6s	remaining: 1.64s
# 942:	learn: 0.3420545	total: 26.6s	remaining: 1.61s
# 943:	learn: 0.3419391	total: 26.6s	remaining: 1.58s
# 944:	learn: 0.3418563	total: 26.7s	remaining: 1.55s
# 945:	learn: 0.3417233	total: 26.7s	remaining: 1.52s
# 946:	learn: 0.3415682	total: 26.7s	remaining: 1.49s
# 947:	learn: 0.3414732	total: 26.7s	remaining: 1.47s
# 948:	learn: 0.3413460	total: 26.8s	remaining: 1.44s
# 949:	learn: 0.3412955	total: 26.8s	remaining: 1.41s
# 950:	learn: 0.3411509	total: 26.8s	remaining: 1.38s
# 951:	learn: 0.3410035	total: 26.8s	remaining: 1.35s
# 952:	learn: 0.3408839	total: 26.9s	remaining: 1.32s
# 953:	learn: 0.3407617	total: 26.9s	remaining: 1.3s
# 954:	learn: 0.3405900	total: 26.9s	remaining: 1.27s
# 955:	learn: 0.3404365	total: 27s	remaining: 1.24s
# 956:	learn: 0.3403189	total: 27s	remaining: 1.21s
# 957:	learn: 0.3402337	total: 27s	remaining: 1.18s
# 958:	learn: 0.3401282	total: 27s	remaining: 1.16s
# 959:	learn: 0.3400578	total: 27.1s	remaining: 1.13s
# 960:	learn: 0.3399235	total: 27.1s	remaining: 1.1s
# 961:	learn: 0.3398093	total: 27.1s	remaining: 1.07s
# 962:	learn: 0.3397361	total: 27.2s	remaining: 1.04s
# 963:	learn: 0.3396303	total: 27.2s	remaining: 1.01s
# 964:	learn: 0.3395485	total: 27.2s	remaining: 987ms
# 965:	learn: 0.3394462	total: 27.2s	remaining: 959ms
# 966:	learn: 0.3393223	total: 27.3s	remaining: 931ms
# 967:	learn: 0.3391793	total: 27.3s	remaining: 903ms
# 968:	learn: 0.3390890	total: 27.3s	remaining: 875ms
# 969:	learn: 0.3390130	total: 27.4s	remaining: 846ms
# 970:	learn: 0.3389396	total: 27.4s	remaining: 818ms
# 971:	learn: 0.3388680	total: 27.4s	remaining: 790ms
# 972:	learn: 0.3387772	total: 27.4s	remaining: 762ms
# 973:	learn: 0.3386638	total: 27.5s	remaining: 733ms
# 974:	learn: 0.3384798	total: 27.5s	remaining: 705ms
# 975:	learn: 0.3383986	total: 27.5s	remaining: 677ms
# 976:	learn: 0.3382422	total: 27.6s	remaining: 649ms
# 977:	learn: 0.3380761	total: 27.6s	remaining: 621ms
# 978:	learn: 0.3379579	total: 27.6s	remaining: 593ms
# 979:	learn: 0.3378698	total: 27.6s	remaining: 564ms
# 980:	learn: 0.3378047	total: 27.7s	remaining: 536ms
# 981:	learn: 0.3376288	total: 27.7s	remaining: 508ms
# 982:	learn: 0.3374313	total: 27.7s	remaining: 480ms
# 983:	learn: 0.3372242	total: 27.8s	remaining: 452ms
# 984:	learn: 0.3371576	total: 27.8s	remaining: 423ms
# 985:	learn: 0.3370144	total: 27.8s	remaining: 395ms
# 986:	learn: 0.3369616	total: 27.9s	remaining: 367ms
# 987:	learn: 0.3369051	total: 27.9s	remaining: 339ms
# 988:	learn: 0.3368242	total: 27.9s	remaining: 310ms
# 989:	learn: 0.3367231	total: 27.9s	remaining: 282ms
# 990:	learn: 0.3366048	total: 28s	remaining: 254ms
# 991:	learn: 0.3365291	total: 28s	remaining: 226ms
# 992:	learn: 0.3364208	total: 28s	remaining: 198ms
# 993:	learn: 0.3363315	total: 28.1s	remaining: 169ms
# 994:	learn: 0.3362912	total: 28.1s	remaining: 141ms
# 995:	learn: 0.3362155	total: 28.1s	remaining: 113ms
# 996:	learn: 0.3360477	total: 28.1s	remaining: 84.7ms
# 997:	learn: 0.3358562	total: 28.2s	remaining: 56.4ms
# 998:	learn: 0.3357409	total: 28.2s	remaining: 28.2ms
# 999:	learn: 0.3356470	total: 28.2s	remaining: 0us
# 0.8898951124567474

# %% [markdown]
# Now we are going to do this on RandomForestClassifier .Lets see how much accuracy we can achieve.

# %%
model=rfc(random_state=0,n_jobs=2,n_estimators=700)
model.fit(df1,y_train)
print(model.score(df1,y_train))
y_pred=model.predict(df2)
subs=pd.DataFrame({'customer_id':test_df['customer_id'][:10],'churn_risk_score':y_pred[:10]})
subs.to_csv('submission_rfc.csv',index=False)
# Out:
# 1.0

# %% [markdown]
# HURRAH !!!!!
#
# We've completed the whole project.
#
# If you like this do not forget to upvote .
#
# and if you have any query or feedback , do comment.
#
# # Thank You for visiting :)
